# %% [markdown]
# <a href="https://colab.research.google.com/github/barblili/2024-7edu-WiDs-datathon-code/blob/main/CancerPatients_2024_Datathon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Data imported from the drive

# %%
import pandas as pd
df_train = pd.read_csv("drive/MyDrive/Datathon 2024/training.csv")

df_train
# Out:
#        patient_id patient_race  payer_type patient_state  patient_zip3  \
# 0          475714          NaN    MEDICAID            CA           924
# 1          349367        White  COMMERCIAL            CA           928
# 2          138632        White  COMMERCIAL            TX           760
# 3          617843        White  COMMERCIAL            CA           926
# 4          817482          NaN  COMMERCIAL            ID           836
# ...           ...          ...         ...           ...           ...
# 12901      674178        White         NaN            OH           436
# 12902      452909          NaN  COMMERCIAL            CA           945
# 12903      357486          NaN  COMMERCIAL            CA           926
# 12904      935417          NaN         NaN            NY           112
# 12905      179597     Hispanic    MEDICAID            FL           336
#
#        patient_age patient_gender    bmi breast_cancer_diagnosis_code  \
# ...

# %%
# Import pandas and cars.csv
import pandas as pd
cancer = pd.read_csv('drive/MyDrive/Datathon 2024/training.csv', index_col = 74)

# Print out country column as Pandas Series
print(cancer['cancer_per_person'])

# Print out country column as Pandas DataFrame
print(cancer[['cars_per_person']])

# Print out DataFrame with country and drives_right columns
print(cancer[['cancer_per_person', 'country']])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'cancer_per_person'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df_train['patient_state'] = df_train['patient_state'].str.lower()
df_train['patient_state'].value_counts().plot(kind='bar', figsize=(10, 5))
plt.xlabel('State')
plt.ylabel('Number of Patients')
plt.show()

df_train['state_population'] = df_train['patient_state'].map(lambda x: state_populations[x])
df_train['state_population_limit'] = df_train['state_population'] / 1000000 * 100
df_train['limit'] = df_train['state_population_limit'].apply(lambda x: min(x, 100))
df_train.head()

df_train = df_train[df_train['limit'] > 0]
df_train.shape
plt.figure();

In [19]: df.iloc[5].plot.bar();

In [20]: plt.axhline(0, color="k");
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-ac414108a7c1> in <cell line: 9>()
#       7 plt.show()
#       8
# ----> 9 df_train['state_population'] = df_train['patient_state'].map(lambda x: state_populations[x])
#      10 df_train['state_population_limit'] = df_train['state_population'] / 1000000 * 100
#      11 df_train['limit'] = df_train['state_population_limit'].apply(lambda x: min(x, 100))
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in map(self, arg, na_action)
#    4537         dtype: object
#    4538         """
# -> 4539         new_values = self._map_values(arg, na_action=na_action)
#    4540         return self._constructor(new_values, index=self.index).__finalize__(
#    4541             self, method="map"
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/base.py in _map_values(self, mapper, na_action)
#     888
# ...

# %%
'Age':[]
